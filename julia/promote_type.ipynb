# %% [markdown]
# ### `promote_type.ipynb`
# *Created June 15, 2026.*
#
# The purpose of this notebook is to explain the `promote_type()` function, and why it matters (and when it doesn't).

# %%
promote_type(eltype([1 2*im; 3 4]), Float64)
