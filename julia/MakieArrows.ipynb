# %%
using Pkg
Pkg.activate("cell_migration_julia_v1.10.0"; shared = true)
# Out:
#   Activating project at `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0`

# %%
Pkg.project().path
# Out:
# "C:\\Users\\mbarm\\.julia\\environments\\cell_migration_julia_v1.10.0\\Project.toml"

# %%
Pkg.status()
# Out:
# Status `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Project.toml`
#   [6e4b80f9] BenchmarkTools v1.6.0
#   [336ed68f] CSV v0.10.15
#   [13f3f980] CairoMakie v0.15.3
#   [5ae59095] Colors v0.13.1
#   [a93c6f00] DataFrames v1.7.0
#   [8bb1440f] DelimitedFiles v1.9.1
#   [0c46a032] DifferentialEquations v7.16.1
#   [31c24e10] Distributions v0.25.120
#   [442a2c76] FastGaussQuadrature v1.0.2
#   [b964fa9f] LaTeXStrings v1.4.0
#   [442fdcdd] Measures v0.3.2
#   [0db19996] NBInclude v2.4.0
#   [bac558e1] OrderedCollections v1.8.1
#   [d236fae5] PreallocationTools v0.4.27
#   [92933f4c] ProgressMeter v1.10.4
#   [2913bbd2] StatsBase v0.34.5
#   [3a884ed6] UnPack v1.0.2
#   [ade2ca70] Dates
#   [37e2e46d] LinearAlgebra
#   [56ddb016] Logging
#   [d6f4376e] Markdown
#   [de0858da] Printf
#   [9a3f8284] Random

# %%
# Out:
# UndefVarError: `DataFrame` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1

# %%
using Pkg

#Create a new environment
Pkg.activate("makie_latest_env"; shared = true)

#Print the filepath of the current environment (to make sure we're in the correct one!) 
Pkg.project().path

# %%
Pkg.project().path

# %%
#Pkg.add("Makie")      #Install Makie 
Pkg.status("Makie")    #Check the version of Makie that was installed

# %%
Pkg.status()   #List all of the packages that are installed in the current environment

# %%
#Pkg.add("CairoMakie")
using CairoMakie
Pkg.status("CairoMakie")

# %%
Pkg.status("CairoMakie")

# %%
using CairoMakie    #The CairoMakie is the plotting backend that we're choosing here because it's fast.

# %%
Pkg.status("CairoMakie")      #CairoMakie v0.6.3

# %%
Pkg.status("Makie")  #Makie v0.15.0

# %%
using Pkg
Pkg.status(; outdated=true)

# %%
fig = Figure()
ax = Axis(fig[1,1])
scatter!(ax, [(0.0, 0.0), (1.0, 1.0)])

# %%
display(fig)

# %%
scale = 1.0
fig = Figure(resolution = scale .* (300, 250))
grid = fig[1, 1] = GridLayout()
ax = Axis(fig[1, 1], title = "my cute plot", aspect = DataAspect(), rightmargin = 0, xlabel = L"x", ylabel = L"y", xlabelsize = 20, ylabelsize = 20)


Box(fig[1, 1], color = (:red, 0.2), strokewidth = 0)
display(fig, px_per_unit = 2)

# %%
fig = Figure(size = (800, 600))
display(fig, px_per_unit = 2);

# %%
using Pkg
Pkg.status("GLMakie")

# %%
Pkg.update("GLMakie")

# %%
Pkg.status("GLMakie")

# %%
using Pkg
Pkg.activate(mktempdir())  # use a temporary clean environment
Pkg.add("GLMakie")

# %%
Pkg
