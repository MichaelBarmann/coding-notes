# %%
#This file contains some ODEs to be used as unit tests for some ODE solvers that I've written from scratch.

# %%
using Plots

# %%
#dy/dt = y (Exponential growth)
function f1(y)
    return y 
end
# Out:
# f1 (generic function with 1 method)

# %%
#dy/dt = -y (Exponential decay)
function f2(y)
    return -y 
end
# Out:
# f2 (generic function with 1 method)

# %%
function f3(y)
    return y^2 
end
# Out:
# f3 (generic function with 1 method)

# %%
prob = ODEProblem(f1, 0.0

# %%
#1) y' = y, y(0) = 1

# %%
#2) y' = -y, y(0) = 1

# %%
#3) y' = y^2, y(0) = 1
