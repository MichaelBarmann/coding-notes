# %%
using Pkg
Pkg.activate("cell_migration_julia_v1.10.0"; shared = true)

#shared = true means: Julia will not create a temporary copy of the environment.
# Out:
#   Activating new project at `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0`

# %%
#Pkg.add("CairoMakie")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Project.toml`
#   [13f3f980] + CairoMakie v0.15.3
#     Updating `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [1520ce14] + AbstractTrees v0.4.5
#   [79e6a3ab] + Adapt v4.3.0
#   [35492f91] + AdaptivePredicates v1.2.0
#   [66dad0bd] + AliasTables v1.1.3
#   [27a7e980] + Animations v0.4.2
#   [67c07d97] + Automa v1.1.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [39de3d68] + AxisArrays v0.4.7
#   [18cc8868] + BaseDirs v1.3.1
#   [fa961155] + CEnum v0.5.0
#   [96374032] + CRlibm v1.0.2
#   [159f3aea] + Cairo v1.1.1
#   [13f3f980] + CairoMakie v0.15.3
#   [d360d2e6] + ChainRulesCore v1.25.2
#   [a2cac450] + ColorBrewer v0.4.1
#   [35d6a980] + ColorSchemes v3.30.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [34da2185] + Compat v4.17.0
# ...

# %%
#Pkg.status("CairoMakie")
# Out:
# Status `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Project.toml`
#   [13f3f980] CairoMakie v0.15.3

# %%
#Pkg.add(["DifferentialEquations", "FastGaussQuadrature", "LinearAlgebra", "PreallocationTools", "DataFrames", "Printf", "LaTeXStrings",
#         "BenchmarkTools", "ProgressMeter", "Markdown", "NBInclude", "OrderedCollections", "Colors", "Random", "StatsBase", "Distributions",
#            "CSV", "DelimitedFiles", "UnPack", "Dates", "Logging"])
# Out:
#    Resolving package versions...
#    Installed BoundaryValueDiffEqCore ───── v1.11.0
#    Installed BoundaryValueDiffEqMIRKN ──── v1.8.0
#    Installed BoundaryValueDiffEqMIRK ───── v1.9.0
#    Installed BoundaryValueDiffEqShooting ─ v1.9.0
#    Installed BoundaryValueDiffEqFIRK ───── v1.9.0
#    Installed RecursiveArrayTools ───────── v3.34.1
#    Installed DiffEqBase ────────────────── v6.177.2
#    Installed OrdinaryDiffEqCore ────────── v1.26.2
#    Installed BoundaryValueDiffEqAscher ─── v1.8.0
#    Installed OrdinaryDiffEqDefault ─────── v1.5.0
#    Installed Moshi ─────────────────────── v0.3.7
#    Installed DifferentiationInterface ──── v0.7.2
#     Updating `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#   [336ed68f] + CSV v0.10.15
#   [5ae59095] + Colors v0.13.1
#   [a93c6f00] + DataFrames v1.7.0
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [0c46a032] + DifferentialEquations v7.16.1
# ...

# %%
#Pkg.add("Measures")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Project.toml`
#   [442fdcdd] + Measures v0.3.2
#     Updating `C:\Users\mbarm\.julia\environments\cell_migration_julia_v1.10.0\Manifest.toml`
#   [442fdcdd] + Measures v0.3.2
# Precompiling project...
#   ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   2 dependencies successfully precompiled in 40 seconds. 480 already precompiled.

# %%
@time using DifferentialEquations
@time using FastGaussQuadrature
@time using LinearAlgebra
@time using PreallocationTools
@time using DataFrames
@time using Printf
@time using LaTeXStrings
@time using BenchmarkTools
@time using ProgressMeter
@time using Markdown
@time using NBInclude
@time using OrderedCollections
@time using Colors
@time using Random
@time using StatsBase
@time using Distributions
@time using CSV
@time using DelimitedFiles
@time using UnPack
@time using Dates
@time using Logging
@time using Measures
@time using CairoMakie

using Base64
using Base: match
using UUIDs
using FFMPEG
using Dates
using UnPack
using Logging
using NBInclude
using OrderedCollections
#ProgressMeter.ijulia_behavior(:clear);
# Out:
#   0.002902 seconds (417 allocations: 30.336 KiB)
#   0.003217 seconds (417 allocations: 30.336 KiB)
#   0.002873 seconds (417 allocations: 30.328 KiB)
#   0.002723 seconds (417 allocations: 30.336 KiB)
#   0.002419 seconds (417 allocations: 30.328 KiB)
#   0.003361 seconds (417 allocations: 30.320 KiB)
#   0.002664 seconds (417 allocations: 30.328 KiB)
#   0.002944 seconds (417 allocations: 30.328 KiB)
#   0.003090 seconds (417 allocations: 30.328 KiB)
#   0.003301 seconds (417 allocations: 30.328 KiB)
#   0.003631 seconds (417 allocations: 30.328 KiB)
#   0.003193 seconds (417 allocations: 30.336 KiB)
#   0.002821 seconds (417 allocations: 30.320 KiB)
#   0.003317 seconds (417 allocations: 30.320 KiB)
#   0.002942 seconds (417 allocations: 30.328 KiB)
#   0.002778 seconds (417 allocations: 30.328 KiB)
#   0.002877 seconds (417 allocations: 30.320 KiB)
#   0.003238 seconds (417 allocations: 30.328 KiB)
#   0.003031 seconds (417 allocations: 30.320 KiB)
# ...
