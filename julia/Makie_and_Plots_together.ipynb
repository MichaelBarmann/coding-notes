# %%
using Pkg

# %%
env_path = "C:/Users/mbarm/.julia/environments/MakiePlots_julia_v1.10.0/Project.toml"
Pkg.activate(env_path)
println("Current environment: ", Pkg.project().path)
# Out:
#   Activating project at `C:\Users\mbarm\.julia\environments\MakiePlots_julia_v1.10.0`
# Current environment: C:\Users\mbarm\.julia\environments\MakiePlots_julia_v1.10.0\Project.toml

# %%
Pkg.status()
# Out:
# Status `C:\Users\mbarm\.julia\environments\MakiePlots_julia_v1.10.0\Project.toml`
#   [13f3f980] CairoMakie v0.15.4
#   [91a5bcdd] Plots v1.40.17

# %%
rm(joinpath(DEPOT_PATH[1], "artifacts"); recursive=true)
# Out:
# IOError: rm("C:\\Users\\mbarm\\.julia\\artifacts\\79f4b10488a13ea285eca6583d8eb63b77756a9e\\bin"): directory not empty (ENOTEMPTY)
#
# Stacktrace:
#  [1] uv_error
#    @ Base .\libuv.jl:100 [inlined]
#  [2] rm(path::String; force::Bool, recursive::Bool)
#    @ Base.Filesystem .\file.jl:307
#  [3] rm(path::String; force::Bool, recursive::Bool) (repeats 2 times)
#    @ Base.Filesystem .\file.jl:294
#  [4] top-level scope
#    @ In[4]:1

# %%
@time using CairoMakie

# %%
using Pkg
Pkg.build("GR")
Pkg.build("Plots")

# %%
using Pkg
Pkg.precompile()

# %%
using Pkg
rm(joinpath(DEPOT_PATH[1], "artifacts"); recursive=true)
